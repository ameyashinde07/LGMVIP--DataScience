# %%
import pandas as pd

# %%
df = pd.read_csv('NSE-TATAGLOBALkhgklg.csv')

# %%
pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in c:\users\ameya\anaconda3\lib\site-packages (0.10.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests>=2.19.0 in c:\users\ameya\anaconda3\lib\site-packages (from pandas_datareader) (2.28.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\ameya\anaconda3\lib\site-packages (from pandas_datareader) (1.4.4)
# Requirement already satisfied: lxml in c:\users\ameya\anaconda3\lib\site-packages (from pandas_datareader) (4.9.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ameya\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ameya\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\ameya\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.21.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ameya\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ameya\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ameya\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ameya\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\ameya\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas_datareader) (1.16.0)

# %%
import pandas_datareader as pdr

# %%
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
 df = df.reset_index()['Close']

# %%
df.shape
# Out:
# (2035,)

# %%
df
# Out:
# 0       233.75
# 1       233.25
# 2       234.25
# 3       236.10
# 4       233.30
#          ...
# 2030    118.65
# 2031    117.60
# 2032    120.65
# 2033    120.90
# 2034    121.55
# Name: Close, Length: 2035, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(df)

# %%
import numpy as np

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
df
# Out:
# array([[0.62418301],
#        [0.62214052],
#        [0.62622549],
#        ...,
#        [0.1621732 ],
#        [0.16319444],
#        [0.16584967]])

# %% [markdown]
# ##training and test split

# %%
training_size=int(len(df)*0.65)
test_size=len(df)-training_size
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
training_size,test_size
# Out:
# (1322, 713)

# %%
train_data
# Out:
# array([[0.62418301],
#        [0.62214052],
#        [0.62622549],
#        ...,
#        [0.25347222],
#        [0.26041667],
#        [0.2563317 ]])

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1221, 100)
# (1221,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 12s 263ms/step - loss: 0.0276 - val_loss: 0.0052
# Epoch 2/100
# 20/20 [==============================] - 3s 153ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 3/100
# 20/20 [==============================] - 3s 153ms/step - loss: 0.0017 - val_loss: 9.4326e-04
# Epoch 4/100
# 20/20 [==============================] - 3s 156ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 5/100
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 6/100
# 20/20 [==============================] - 3s 154ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 7/100
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 8/100
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 9/100
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 10/100
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 11/100
# 20/20 [==============================] - 3s 154ms/step - loss: 0.0010 - val_loss: 9.1741e-04
# Epoch 12/100
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 13/100
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 14/100
# 20/20 [==============================] - 3s 161ms/step - loss: 9.7923e-04 - val_loss: 8.9143e-04
# Epoch 15/100
# 20/20 [==============================] - 3s 163ms/step - loss: 9.2011e-04 - val_loss: 7.4423e-04
# Epoch 16/100
# 20/20 [==============================] - 3s 163ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 17/100
# 20/20 [==============================] - 3s 164ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 18/100
# 20/20 [==============================] - 3s 164ms/step - loss: 8.4037e-04 - val_loss: 8.5485e-04
# Epoch 19/100
# 20/20 [==============================] - 3s 159ms/step - loss: 8.0323e-04 - val_loss: 8.4381e-04
# Epoch 20/100
# 20/20 [==============================] - 3s 155ms/step - loss: 7.6713e-04 - val_loss: 8.4072e-04
# Epoch 21/100
# 20/20 [==============================] - 3s 161ms/step - loss: 7.4045e-04 - val_loss: 7.0442e-04
# Epoch 22/100
# 20/20 [==============================] - 3s 164ms/step - loss: 7.2482e-04 - val_loss: 7.3109e-04
# Epoch 23/100
# 20/20 [==============================] - 3s 161ms/step - loss: 7.4339e-04 - val_loss: 6.3332e-04
# Epoch 24/100
# 20/20 [==============================] - 3s 159ms/step - loss: 7.7953e-04 - val_loss: 7.9162e-04
# Epoch 25/100
# 20/20 [==============================] - 3s 157ms/step - loss: 7.1976e-04 - val_loss: 8.0964e-04
# Epoch 26/100
# 20/20 [==============================] - 3s 157ms/step - loss: 6.9032e-04 - val_loss: 7.7405e-04
# Epoch 27/100
# 20/20 [==============================] - 3s 160ms/step - loss: 6.9008e-04 - val_loss: 6.5717e-04
# Epoch 28/100
# 20/20 [==============================] - 3s 156ms/step - loss: 6.4904e-04 - val_loss: 6.9847e-04
# Epoch 29/100
# 20/20 [==============================] - 3s 155ms/step - loss: 7.1023e-04 - val_loss: 6.2595e-04
# Epoch 30/100
# 20/20 [==============================] - 3s 155ms/step - loss: 7.0188e-04 - val_loss: 5.9089e-04
# Epoch 31/100
# 20/20 [==============================] - 3s 156ms/step - loss: 6.0628e-04 - val_loss: 6.4355e-04
# Epoch 32/100
# 20/20 [==============================] - 3s 155ms/step - loss: 5.9857e-04 - val_loss: 6.1152e-04
# Epoch 33/100
# 20/20 [==============================] - 3s 155ms/step - loss: 6.1587e-04 - val_loss: 7.1401e-04
# Epoch 34/100
# 20/20 [==============================] - 3s 154ms/step - loss: 5.8360e-04 - val_loss: 6.9997e-04
# Epoch 35/100
# 20/20 [==============================] - 3s 154ms/step - loss: 6.1173e-04 - val_loss: 6.4279e-04
# Epoch 36/100
# 20/20 [==============================] - 3s 156ms/step - loss: 6.3649e-04 - val_loss: 5.9898e-04
# Epoch 37/100
# 20/20 [==============================] - 3s 154ms/step - loss: 5.5409e-04 - val_loss: 5.6987e-04
# Epoch 38/100
# 20/20 [==============================] - 3s 153ms/step - loss: 5.6213e-04 - val_loss: 6.4521e-04
# Epoch 39/100
# 20/20 [==============================] - 3s 153ms/step - loss: 5.4149e-04 - val_loss: 6.2468e-04
# Epoch 40/100
# 20/20 [==============================] - 3s 159ms/step - loss: 5.4547e-04 - val_loss: 5.9368e-04
# Epoch 41/100
# 20/20 [==============================] - 3s 162ms/step - loss: 5.4722e-04 - val_loss: 4.9252e-04
# Epoch 42/100
# 20/20 [==============================] - 3s 158ms/step - loss: 5.7999e-04 - val_loss: 5.1048e-04
# Epoch 43/100
# 20/20 [==============================] - 3s 161ms/step - loss: 5.2577e-04 - val_loss: 5.7795e-04
# Epoch 44/100
# 20/20 [==============================] - 3s 159ms/step - loss: 6.7483e-04 - val_loss: 0.0011
# Epoch 45/100
# 20/20 [==============================] - 3s 159ms/step - loss: 5.3963e-04 - val_loss: 6.0320e-04
# Epoch 46/100
# 20/20 [==============================] - 3s 157ms/step - loss: 5.0193e-04 - val_loss: 4.2731e-04
# Epoch 47/100
# 20/20 [==============================] - 3s 158ms/step - loss: 5.2618e-04 - val_loss: 6.2382e-04
# Epoch 48/100
# 20/20 [==============================] - 3s 163ms/step - loss: 4.7794e-04 - val_loss: 5.0938e-04
# Epoch 49/100
# 20/20 [==============================] - 3s 156ms/step - loss: 4.8590e-04 - val_loss: 5.9225e-04
# Epoch 50/100
# 20/20 [==============================] - 3s 156ms/step - loss: 4.8029e-04 - val_loss: 4.4812e-04
# Epoch 51/100
# 20/20 [==============================] - 3s 151ms/step - loss: 4.5951e-04 - val_loss: 4.8154e-04
# Epoch 52/100
# 20/20 [==============================] - 3s 153ms/step - loss: 4.8890e-04 - val_loss: 4.7668e-04
# Epoch 53/100
# 20/20 [==============================] - 3s 155ms/step - loss: 4.4719e-04 - val_loss: 5.2775e-04
# Epoch 54/100
# 20/20 [==============================] - 3s 154ms/step - loss: 4.8311e-04 - val_loss: 4.7261e-04
# Epoch 55/100
# 20/20 [==============================] - 3s 157ms/step - loss: 5.1873e-04 - val_loss: 3.8072e-04
# Epoch 56/100
# 20/20 [==============================] - 3s 159ms/step - loss: 4.4244e-04 - val_loss: 5.5465e-04
# Epoch 57/100
# 20/20 [==============================] - 3s 157ms/step - loss: 4.8867e-04 - val_loss: 5.0737e-04
# Epoch 58/100
# 20/20 [==============================] - 3s 154ms/step - loss: 4.0557e-04 - val_loss: 3.5742e-04
# Epoch 59/100
# 20/20 [==============================] - 3s 157ms/step - loss: 4.8009e-04 - val_loss: 4.4849e-04
# Epoch 60/100
# 20/20 [==============================] - 3s 156ms/step - loss: 4.2718e-04 - val_loss: 4.2047e-04
# Epoch 61/100
# 20/20 [==============================] - 3s 152ms/step - loss: 4.1273e-04 - val_loss: 5.1950e-04
# Epoch 62/100
# 20/20 [==============================] - 3s 153ms/step - loss: 4.1320e-04 - val_loss: 4.5578e-04
# Epoch 63/100
# 20/20 [==============================] - 3s 153ms/step - loss: 4.4192e-04 - val_loss: 4.6838e-04
# Epoch 64/100
# 20/20 [==============================] - 3s 154ms/step - loss: 4.6097e-04 - val_loss: 3.7366e-04
# Epoch 65/100
# 20/20 [==============================] - 3s 155ms/step - loss: 4.1085e-04 - val_loss: 3.2865e-04
# Epoch 66/100
# 20/20 [==============================] - 3s 153ms/step - loss: 4.3995e-04 - val_loss: 4.1595e-04
# Epoch 67/100
# 20/20 [==============================] - 3s 154ms/step - loss: 3.8206e-04 - val_loss: 4.7825e-04
# Epoch 68/100
# 20/20 [==============================] - 3s 154ms/step - loss: 4.1879e-04 - val_loss: 3.4040e-04
# Epoch 69/100
# 20/20 [==============================] - 3s 154ms/step - loss: 3.7713e-04 - val_loss: 3.1644e-04
# Epoch 70/100
# 20/20 [==============================] - 3s 157ms/step - loss: 3.7249e-04 - val_loss: 3.0920e-04
# Epoch 71/100
# 20/20 [==============================] - 3s 158ms/step - loss: 3.6876e-04 - val_loss: 4.5671e-04
# Epoch 72/100
# 20/20 [==============================] - 3s 159ms/step - loss: 3.6408e-04 - val_loss: 3.3753e-04
# Epoch 73/100
# 20/20 [==============================] - 3s 156ms/step - loss: 3.3106e-04 - val_loss: 4.0111e-04
# Epoch 74/100
# 20/20 [==============================] - 3s 156ms/step - loss: 3.2151e-04 - val_loss: 3.1551e-04
# Epoch 75/100
# 20/20 [==============================] - 3s 154ms/step - loss: 3.4367e-04 - val_loss: 3.3617e-04
# Epoch 76/100
# 20/20 [==============================] - 3s 159ms/step - loss: 3.1753e-04 - val_loss: 2.9088e-04
# Epoch 77/100
# 20/20 [==============================] - 3s 159ms/step - loss: 3.4151e-04 - val_loss: 3.7406e-04
# Epoch 78/100
# 20/20 [==============================] - 3s 166ms/step - loss: 3.0620e-04 - val_loss: 2.5605e-04
# Epoch 79/100
# 20/20 [==============================] - 3s 159ms/step - loss: 3.8067e-04 - val_loss: 2.7929e-04
# Epoch 80/100
# 20/20 [==============================] - 3s 158ms/step - loss: 3.4418e-04 - val_loss: 3.0706e-04
# Epoch 81/100
# 20/20 [==============================] - 3s 162ms/step - loss: 5.2361e-04 - val_loss: 2.6240e-04
# Epoch 82/100
# 20/20 [==============================] - 3s 162ms/step - loss: 3.1122e-04 - val_loss: 4.5406e-04
# Epoch 83/100
# 20/20 [==============================] - 3s 159ms/step - loss: 4.3006e-04 - val_loss: 2.6844e-04
# Epoch 84/100
# 20/20 [==============================] - 3s 157ms/step - loss: 3.9745e-04 - val_loss: 3.2924e-04
# Epoch 85/100
# 20/20 [==============================] - 3s 154ms/step - loss: 2.7620e-04 - val_loss: 2.2430e-04
# Epoch 86/100
# 20/20 [==============================] - 3s 153ms/step - loss: 3.3609e-04 - val_loss: 4.3075e-04
# Epoch 87/100
# 20/20 [==============================] - 3s 153ms/step - loss: 3.5043e-04 - val_loss: 2.5364e-04
# Epoch 88/100
# 20/20 [==============================] - 3s 154ms/step - loss: 2.9286e-04 - val_loss: 2.6368e-04
# Epoch 89/100
# 20/20 [==============================] - 3s 151ms/step - loss: 3.0650e-04 - val_loss: 2.9335e-04
# Epoch 90/100
# 20/20 [==============================] - 3s 152ms/step - loss: 2.8721e-04 - val_loss: 3.2043e-04
# Epoch 91/100
# 20/20 [==============================] - 3s 154ms/step - loss: 3.2550e-04 - val_loss: 2.4283e-04
# Epoch 92/100
# 20/20 [==============================] - 3s 151ms/step - loss: 2.9751e-04 - val_loss: 2.7329e-04
# Epoch 93/100
# 20/20 [==============================] - 3s 152ms/step - loss: 2.5580e-04 - val_loss: 2.7959e-04
# Epoch 94/100
# 20/20 [==============================] - 3s 151ms/step - loss: 3.1723e-04 - val_loss: 2.6078e-04
# Epoch 95/100
# 20/20 [==============================] - 3s 151ms/step - loss: 2.9275e-04 - val_loss: 2.6116e-04
# Epoch 96/100
# 20/20 [==============================] - 3s 152ms/step - loss: 2.4567e-04 - val_loss: 2.1477e-04
# Epoch 97/100
# 20/20 [==============================] - 3s 151ms/step - loss: 2.3807e-04 - val_loss: 2.5015e-04
# Epoch 98/100
# 20/20 [==============================] - 3s 151ms/step - loss: 2.5110e-04 - val_loss: 2.1218e-04
# Epoch 99/100
# 20/20 [==============================] - 3s 152ms/step - loss: 2.3444e-04 - val_loss: 2.4321e-04
# Epoch 100/100
# 20/20 [==============================] - 3s 154ms/step - loss: 2.4252e-04 - val_loss: 2.2206e-04

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.11.0'

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 39/39 [==============================] - 2s 30ms/step
# 20/20 [==============================] - 1s 28ms/step

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 166.3740956691856

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 116.15558863030222

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 713

# %%
x_input=test_data[341:].reshape(1,-1)
x_input.shape
# Out:
# (1, 372)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.048815359477124176,
#  0.048815359477124176,
#  0.05310457516339867,
#  0.049632352941176405,
#  0.05065359477124176,
#  0.05126633986928103,
#  0.049632352941176405,
#  0.05902777777777779,
#  0.055555555555555525,
#  0.040849673202614345,
#  0.037377450980392135,
#  0.037377450980392135,
#  0.026552287581699308,
#  0.02879901960784309,
#  0.03165849673202614,
#  0.03165849673202614,
#  0.036356209150326724,
#  0.022058823529411742,
#  0.016748366013071836,
#  0.014501633986928053,
#  0.022263071895424813,
#  0.03615196078431371,
#  0.02675653594771238,
#  0.03206699346405223,
#  0.02696078431372545,
#  0.035743464052287566,
#  0.03594771241830064,
#  0.0404411764705882,
#  0.039215686274509776,
#  0.044117647058823484,
#  0.029820261437908446,
#  0.012254901960784326,
#  0.012867647058823484,
#  0.09803922 0.09987745 0.08925654 0.0747549  0.08169935 0.08925654
#  0.09068627 0.08129085 0.08823529 0.08455882 0.07945261 0.08374183
#  0.07781863 0.09824346 0.09089052 0.09007353 0.09558824 0.06862745
#  0.06372549 0.0494281  0.04799837 0.04534314 0.0443219  0.03941993
#  0.0379902  0.04656863 0.05085784 0.07209967 0.06535948 0.07230392
#  0.07802288 0.07741013 0.06086601 0.06413399 0.07046569 0.05412582
#  0.0498366  0.05167484 0.05330882 0.0435049  0.02634804 0.02410131
#  0.02961601 0.01960784 0.02961601 0.04575163 0.05923203 0.06678922
#  0.06229575 0.06311275 0.0629085  0.06658497 0.07434641 0.06944444
#  0.08088235 0.07700163 0.0684232  0.06781046 0.0629085  0.0692402
#  0.0755719  0.07781863 0.08088235 0.08843954 0.09395425 0.09599673
#  0.08660131 0.09027778 0.08517157 0.08374183 0.07945261 0.09109477
#  0.09129902 0.08803105 0.09681373 0.11417484 0.10498366 0.09987745
#  0.08537582 0.08047386 0.06862745 0.06576797 0.06147876 0.07169118
#  0.07026144 0.0747549  0.06821895 0.0692402  0.07066993 0.06801471
#  0.06678922 0.07414216 0.07169118 0.08639706 0.08312908 0.06311275
#  0.0629085  0.05167484 0.03186275 0.04003268 0.03860294 0.04105392
#  0.03390523 0.03125    0.02634804 0.05861928 0.06311275 0.0620915
#  0.05535131 0.08455882 0.05514706 0.06045752 0.0557598  0.0439134
#  0.02920752 0.02818627 0.04718137 0.06045752 0.05861928 0.06168301
#  0.06699346 0.07087418 0.0755719  0.07700163 0.10375817 0.10314542
#  0.10334967 0.10089869 0.10437092 0.09803922 0.09722222 0.09783497
#  0.09579248 0.09109477 0.09313725 0.08558007 0.09517974 0.11172386
#  0.12275327 0.12806373 0.1313317  0.12479575 0.11090686 0.10743464
#  0.11621732 0.11683007 0.11764706 0.12888072 0.12847222 0.13337418
#  0.14236111 0.14093137 0.13970588 0.13827614 0.13541667 0.13010621
#  0.12254902 0.12479575 0.13848039 0.14011438 0.13888889 0.13541667
#  0.14011438 0.1380719  0.13071895 0.13071895 0.12867647 0.11846405
#  0.14644608 0.14808007 0.15910948 0.15992647 0.15788399 0.16441993
#  0.17892157 0.17933007 0.19260621 0.20812908 0.18974673 0.18055556
#  0.18239379 0.17708333 0.17810458 0.18055556 0.17810458 0.17851307
#  0.19607843 0.18913399 0.18954248 0.19403595 0.19444444 0.20200163
#  0.19771242 0.19934641 0.19873366 0.1997549  0.2128268  0.21568627
#  0.20445261 0.21772876 0.21098856 0.21425654 0.19750817 0.18811275
#  0.17851307 0.17381536 0.16033497 0.16564542 0.17116013 0.17422386
#  0.18035131 0.17401961 0.16278595 0.16973039 0.17810458 0.17034314
#  0.16830065 0.17279412 0.17544935 0.18382353 0.19138072 0.18913399
#  0.19097222 0.17238562 0.16830065 0.1693219  0.17177288 0.16156046
#  0.14971405 0.1503268  0.15196078 0.14726307 0.14501634 0.14603758
#  0.12479575 0.13112745 0.11397059 0.1190768  0.12377451 0.13562092
#  0.12908497 0.13459967 0.12806373 0.13031046 0.12724673 0.13521242
#  0.14522059 0.15257353 0.14848856 0.14338235 0.14562908 0.15236928
#  0.15400327 0.14971405 0.1621732  0.16319444 0.16584967]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2348\917492977.py in <module>
#      12         print("{} day input {}".format(i,x_input))
#      13         x_input=x_input.reshape(1,-1)
# ---> 14         x_input = x_input.reshape((1, n_steps, 1))
#      15         #print(x_input)
#      16         yhat = model.predict(x_input, verbose=0)
#
# ValueError: cannot reshape array of size 371 into shape (1,100,1)

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
import matplotlib.pyplot as plt

# %%
len(df)
# Out:
# 2035

# %%
plt.plot(day_new,scaler.inverse_transform(df[1935:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2348\1925267263.py in <module>
#       1 plt.plot(day_new,scaler.inverse_transform(df[1935:]))
# ----> 2 plt.plot(day_pred,scaler.inverse_transform(lst_output))
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in inverse_transform(self, X)
#     523         check_is_fitted(self)
#     524
# --> 525         X = check_array(
#     526             X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     527         )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     767             # If input is 1D raise error
#     768             if array.ndim == 1:
# --> 769                 raise ValueError(
#     770                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     771                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
df3=df.tolist()
df3.extend(lst_output)
plt.plot(df3[2000:])

# %%
df3=scaler.inverse_transform(df3).tolist()
plt.plot(df3)
